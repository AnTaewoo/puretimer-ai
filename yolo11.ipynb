# %%
import torch
from ultralytics import YOLO

# CUDA 사용 가능 여부 확인
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA Device:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("Using CPU instead")

torch.backends.cudnn.benchmark = True
torch.backends.cudnn.enabled = True

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/root/puretimer-ai/dataset/data.yaml",  # path to dataset YAML
    epochs=100,  # number of training epochs
    imgsz=640,  # training image size
    device=device,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# CUDA Device: NVIDIA RTX A5000
# ...

# %%
# Evaluate model performance on the validation set
metrics = model.val()

# Perform object detection on an image
results = model("/root/puretimer-ai/test1.jpg")
results[0].show()

# Export the model to ONNX format
path = model.export(format="onnx")  # return path to exported model
# Out:
# Ultralytics 8.3.44 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA RTX A5000, 24142MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /root/puretimer-ai/dataset/valid/labels.cache... 148 images, 0 backgrounds, 0 corrupt: 100%|██████████| 148/148 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 82, len(boxes) = 156. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:01<00:00,  5.50it/s]
#                    all        148        156      0.464      0.621      0.502      0.404
#                      0          1          1    0.00923      0.286     0.0321     0.0257
# ...

# %%
import cv2

img = cv2.imread('/root/puretimer-ai/test1.jpg')  # 감지할 이미지

# 객체 감지 수행
results = model(img)

# 예측 결과에서 감지된 객체와 그 신뢰도를 가져옵니다.
# `results` 객체에는 예측된 객체 정보가 저장됩니다.
# 결과를 pandas DataFrame 형식으로 추출합니다.
predictions = results[0]  # 첫 번째 이미지에서 예측된 결과
print(predictions)

# 결과 출력
for _, row in predictions.iterrows():
    x1, y1, w, h, confidence, class_id = row[['x', 'y', 'width', 'height', 'confidence', 'class']]

    # 클래스 이름을 가져옵니다 (선택적으로).
    class_names = results.names
    label = f'{class_names[int(class_id)]}: {confidence:.2f}'  # 예: 'person: 0.85'

    # 바운딩 박스 좌표 계산
    x2, y2 = x1 + w, y1 + h

    # 바운딩 박스와 신뢰도 레이블을 이미지에 표시
    cv2.rectangle(img, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)  # 바운딩 박스 그리기
    cv2.putText(img, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)  # 레이블 표시

# 감지된 이미지 보기
cv2.imshow("Detected Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# 결과 이미지를 저장하고 싶다면 아래를 추가
cv2.imwrite("output_image.jpg", img)
# Out:
# 0: 448x640 1 phone, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: '0', 1: '123', 2: 'Mobile phone', 3: 'phone'}
# obb: None
# orig_img: array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [201, 216, 225],
#         [200, 215, 224],
#         [199, 214, 223]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [201, 216, 225],
#         [200, 215, 224],
#         [200, 215, 224]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [201, 216, 225],
#         [201, 216, 225],
#         [200, 215, 224]],
#
#        ...,
#
#        [[ 61,  78,  97],
#         [ 63,  80,  99],
#         [ 65,  80,  99],
# ...
